# %% [markdown]
# # The analysis from main dataset

# %% [markdown]
# ## Loading Imports

# %%
import sys
import pandas as pd
import json
from pathlib import Path

sys.path.append(str(Path().resolve().parents[0]))

from src import extract_data
# Out:
# fd21fef63066156a703338994f86b23b

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
DATA_PATH = extract_data.extract_path_from_file('data', 'weather_data.json')

# %% [markdown]
# ## Visual Overview  from data

# %%
with open(DATA_PATH) as json_data:
    data = json.load(json_data)
    

df = pd.json_normalize(data) if isinstance (data, dict) else []

print(df.head())
# Out:
#                                                                        weather  \
# 0  [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}]
#
#        base  visibility          dt  timezone       id       name  cod  \
# 0  stations       10000  1772624152    -10800  3448439  São Paulo  200
#
#    coord.lon  coord.lat  main.temp  main.feels_like  main.temp_min  \
# 0   -46.6361   -23.5475     293.05           293.11          292.9
#
#    main.temp_max  main.pressure  main.humidity  main.sea_level  \
# 0         293.35           1016             77            1016
#
#    main.grnd_level  wind.speed  wind.deg  clouds.all  sys.type  sys.id  \
# 0              926        2.06       110          20         1    8394
#
#   sys.country  sys.sunrise  sys.sunset
# 0          BR   1772615013  1772660000

# %% [markdown]
# ## Data type distribution

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 26 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   weather          1 non-null      object
#  1   base             1 non-null      object
#  2   visibility       1 non-null      int64
#  3   dt               1 non-null      int64
#  4   timezone         1 non-null      int64
#  5   id               1 non-null      int64
#  6   name             1 non-null      object
#  7   cod              1 non-null      int64
#  8   coord.lon        1 non-null      float64
#  9   coord.lat        1 non-null      float64
#  10  main.temp        1 non-null      float64
#  11  main.feels_like  1 non-null      float64
#  12  main.temp_min    1 non-null      float64
#  13  main.temp_max    1 non-null      float64
#  14  main.pressure    1 non-null      int64
#  15  main.humidity    1 non-null      int64
#  16  main.sea_level   1 non-null      int64
# ...

# %%
df
# Out:
#                                                                        weather  \
# 0  [{'id': 801, 'main': 'Clouds', 'description': 'few clouds', 'icon': '02d'}]
#
#        base  visibility          dt  timezone       id       name  cod  \
# 0  stations       10000  1772624152    -10800  3448439  São Paulo  200
#
#    coord.lon  coord.lat  main.temp  main.feels_like  main.temp_min  \
# 0   -46.6361   -23.5475     293.05           293.11          292.9
#
#    main.temp_max  main.pressure  main.humidity  main.sea_level  \
# 0         293.35           1016             77            1016
#
#    main.grnd_level  wind.speed  wind.deg  clouds.all  sys.type  sys.id  \
# 0              926        2.06       110          20         1    8394
#
#   sys.country  sys.sunrise  sys.sunset
# 0          BR   1772615013  1772660000
